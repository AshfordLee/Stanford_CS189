# %%
import scipy 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cov_matrix=np.load("./cov_matrix_digit_0.npy")

# %%
plt.figure(figsize=(8,6))
plt.imshow(cov_matrix,cmap='hot')
plt.colorbar()
plt.title(f'Covariance Matrix for digit {digit}')
plt.show()

# %%
diag=np.diag(cov_matrix)
non_diag=cov_matrix[np.triu_indices_from(cov_matrix,k=1)]

print(f"Diagonal elements mean: {np.mean(diag)}")
print(f"Non-diagonal elements mean: {np.mean(non_diag)}")
# Out:
# Diagonal elements mean: 0.0005417432359941628
# Non-diagonal elements mean: 2.077706833840973e-06
