# %%
import pandas as pd
import numpy as np

# %%
auto=pd.read_csv("./Auto.csv")
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
auto=auto.dropna()

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
quant_cols=auto.select_dtypes(include=['number']).columns
quant_cols.to_list()
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'weight',
#  'acceleration',
#  'year',
#  'origin']

# %%
quant_series=auto.select_dtypes(include=['number'])

min_values=quant_series.min()
max_values=quant_series.max()

min_values
# Out:
# mpg                9.0
# cylinders          3.0
# displacement      68.0
# weight          1613.0
# acceleration       8.0
# year              70.0
# origin             1.0
# dtype: float64

# %%
max_values
# Out:
# mpg               46.6
# cylinders          8.0
# displacement     455.0
# weight          5140.0
# acceleration      24.8
# year              82.0
# origin             3.0
# dtype: float64

# %%
quant_series.mean()
# Out:
# mpg               23.515869
# cylinders          5.458438
# displacement     193.532746
# weight          2970.261965
# acceleration      15.555668
# year              75.994962
# origin             1.574307
# dtype: float64

# %%
quant_series.std()
# Out:
# mpg               7.825804
# cylinders         1.701577
# displacement    104.379583
# weight          847.904119
# acceleration      2.749995
# year              3.690005
# origin            0.802549
# dtype: float64

# %%
auto_slice=auto.drop(range(9,85))
auto_slice
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
quant_series_slice=auto_slice.select_dtypes(include=['number'])

quant_series_slice.max()-quant_series_slice.min()
# Out:
# mpg               35.6
# cylinders          5.0
# displacement     387.0
# weight          3348.0
# acceleration      16.3
# year              12.0
# origin             2.0
# dtype: float64

# %%
quant_series_slice.mean()
# Out:
# mpg               24.438629
# cylinders          5.370717
# displacement     187.049844
# weight          2933.962617
# acceleration      15.723053
# year              77.152648
# origin             1.598131
# dtype: float64

# %%
quant_series_slice.std()
# Out:
# mpg               7.908184
# cylinders         1.653486
# displacement     99.635385
# weight          810.642938
# acceleration      2.680514
# year              3.111230
# origin            0.816163
# dtype: float64

# %%
pd.plotting.scatter_matrix(auto[['mpg','cylinders','displacement']])
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
#         <Axes: xlabel='displacement', ylabel='displacement'>]],
#       dtype=object)
